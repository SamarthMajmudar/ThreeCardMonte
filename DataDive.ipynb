# %% [markdown]
# <a href="https://colab.research.google.com/github/SamarthMajmudar/ThreeCardMonte/blob/main/DataDive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
display(df.head())
display(df.info())
# Out:
#    year   FAMPOV  PCTPOV       POV
# 0  1959  7507000    22.1  17628000
# 1  1960  7780000    19.5  16328000
# 2  1961  7268000    18.2  15853000
# 3  1962  6887000    15.9  14988000
# 4  1963  6010000    14.5  14259000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    65 non-null     int64
#  1   FAMPOV  65 non-null     int64
#  2   PCTPOV  65 non-null     float64
#  3   POV     65 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 2.2 KB
# None

# %%
file_path = '/content/drive/MyDrive/us_poverty_histpov2.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#     year   FAMPOV  PCTPOV       POV
# 0   1959  7507000    22.1  17628000
# 1   1960  7780000    19.5  16328000
# 2   1961  7268000    18.2  15853000
# 3   1962  6887000    15.9  14988000
# 4   1963  6010000    14.5  14259000
# ..   ...      ...     ...       ...
# 60  2019  3529000    11.4  16672200
# 61  2020  3963000    12.4  21900100
# 62  2021  3294000    10.5  16422700
# 63  2022  3456000    11.0  17614000
# 64  2023  3487000    11.1  17628300
#
# [65 rows x 4 columns]

# %%
df.plot.line(x = "year", y = "PCTPOV", xlabel = "Year", ylabel = "Poverty Rate", title = "Poverty Rate over the years")
# Out:
# <Axes: title={'center': 'Poverty Rate over the years'}, xlabel='Year', ylabel='Poverty Rate'>

# %%
df_2010 = df[df.year >= 2010]
df_2010
# Out:
#     year   FAMPOV  PCTPOV       POV
# 51  2010  4903000    13.7  20562700
# 52  2011  4534000    13.0  19073200
# 53  2012  4478000    13.0  18823700
# 54  2013  4628000    13.5  20860200
# 55  2014  4389000    13.2  20628600
# 56  2015  4124000    12.7  19176000
# 57  2016  3956000    12.3  19051800
# 58  2017  3759000    11.8  18063300
# 59  2018  3584000    11.3  16745300
# 60  2019  3529000    11.4  16672200
# 61  2020  3963000    12.4  21900100
# 62  2021  3294000    10.5  16422700
# 63  2022  3456000    11.0  17614000
# 64  2023  3487000    11.1  17628300

# %%
df_2010.plot.line(x = "year", y = "PCTPOV", xlabel = "Year", ylabel = "Poverty Rate", title = "Poverty Rate over the years")
# Out:
# <Axes: title={'center': 'Poverty Rate over the years'}, xlabel='Year', ylabel='Poverty Rate'>
